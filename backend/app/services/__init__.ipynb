# %% [markdown]
# # Services Package
#
# Application/business logic for the AI Study Companion.
#
# Services sit between FastAPI routes and the underlying
# database, AI, retrieval, and background-processing layers.
